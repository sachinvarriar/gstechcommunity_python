# %% [markdown]
# <a href="https://colab.research.google.com/github/sachinvarriar/gstechcommunity_python/blob/main/pandas_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
DF=pd.read_csv("sample_data/california_housing_train.csv")

# %%
DF.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
DF.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
DF.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
DF.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
DF = DF.drop('longitude', axis=1)

# %%
DF = DF.drop(['longitude','latitude'], axis=1)

# %%
DF
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    15.0       5612.0          1283.0      1015.0
# 1                    19.0       7650.0          1901.0      1129.0
# 2                    17.0        720.0           174.0       333.0
# 3                    14.0       1501.0           337.0       515.0
# 4                    20.0       1454.0           326.0       624.0
# ...                   ...          ...             ...         ...
# 16995                52.0       2217.0           394.0       907.0
# 16996                36.0       2349.0           528.0      1194.0
# 16997                17.0       2677.0           531.0      1244.0
# 16998                19.0       2672.0           552.0      1298.0
# 16999                52.0       1820.0           300.0       806.0
#
#        households  median_income  median_house_value
# 0           472.0         1.4936             66900.0
# 1           463.0         1.8200             80100.0
# ...

# %%
print(DF['housing_median_age'].min())
print(DF['housing_median_age'].max())
# Out:
# 1.0
# 52.0

# %%
DF['median_income']=DF['median_income'].astype(str)

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   housing_median_age  17000 non-null  float64
#  1   total_rooms         17000 non-null  float64
#  2   total_bedrooms      17000 non-null  float64
#  3   population          17000 non-null  float64
#  4   households          17000 non-null  float64
#  5   median_income       17000 non-null  object
#  6   median_house_value  17000 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 929.8+ KB

# %%
DF['median_income']=DF['median_income'].astype(float)

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   housing_median_age  17000 non-null  float64
#  1   total_rooms         17000 non-null  float64
#  2   total_bedrooms      17000 non-null  float64
#  3   population          17000 non-null  float64
#  4   households          17000 non-null  float64
#  5   median_income       17000 non-null  float64
#  6   median_house_value  17000 non-null  float64
# dtypes: float64(7)
# memory usage: 929.8 KB

# %%
DF.nlargest(4,'total_rooms', keep = 'all')
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 2871                  4.0      37937.0          5471.0     16122.0
# 12772                11.0      32627.0          6445.0     28566.0
# 2969                  8.0      32054.0          5290.0     15507.0
# 8881                  9.0      30405.0          4093.0     12873.0
#
#        households  median_income  median_house_value
# 2871       5189.0         7.4947            366300.0
# 12772      6082.0         2.3087            118800.0
# 2969       5050.0         6.0191            253900.0
# 8881       3931.0         8.0137            399200.0

# %%
DF.nlargest(4,'housing_median_age', keep = 'all')
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 325                  52.0       3419.0           777.0       710.0
# 1011                 52.0       2606.0           426.0       883.0
# 1074                 52.0       1506.0           233.0       478.0
# 1075                 52.0       1484.0           224.0       498.0
# 1103                 52.0        280.0            71.0       217.0
# ...                   ...          ...             ...         ...
# 16971                52.0       1557.0           344.0       758.0
# 16992                52.0       1112.0           209.0       544.0
# 16993                52.0       2694.0           453.0      1152.0
# 16995                52.0       2217.0           394.0       907.0
# 16999                52.0       1820.0           300.0       806.0
#
#        households  median_income  median_house_value
# 325         265.0         3.9028            128600.0
# 1011        380.0         4.2813            270800.0
# ...

# %%
DF.nlargest(4,'housing_median_age', keep = 'first')
# Out:
#       housing_median_age  total_rooms  total_bedrooms  population  households  \
# 325                 52.0       3419.0           777.0       710.0       265.0
# 1011                52.0       2606.0           426.0       883.0       380.0
# 1074                52.0       1506.0           233.0       478.0       240.0
# 1075                52.0       1484.0           224.0       498.0       223.0
#
#       median_income  median_house_value
# 325          3.9028            128600.0
# 1011         4.2813            270800.0
# 1074         4.3875            300000.0
# 1075         6.6053            331400.0

# %%
DF.sort_values('housing_median_age', ascending= False)
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 16999                52.0       1820.0           300.0       806.0
# 14561                52.0       1888.0           457.0       830.0
# 6551                 52.0       2602.0           418.0      1137.0
# 4420                 52.0       2792.0           461.0      1177.0
# 14579                52.0        771.0           147.0       355.0
# ...                   ...          ...             ...         ...
# 1880                  2.0       1658.0           290.0       868.0
# 4274                  2.0       2701.0           530.0      1368.0
# 2771                  2.0       5261.0           763.0      1460.0
# 10993                 1.0       2254.0           328.0       402.0
# 13708                 1.0       2062.0           343.0       872.0
#
#        households  median_income  median_house_value
# 16999       270.0         3.0147             94600.0
# 14561       408.0         3.1373            185100.0
# ...
